# %%
# Elbow method to generate optimal number of clusters
from sklearn.cluster import KMeans

wcss = []
for k in range(1, 11):  # Test k from 1 to 10
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker="o")
plt.title("Elbow Method for Optimal Number of Clusters")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.xticks(range(1, 11))
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
    df["longitude_house"],
    df["latitude_house"],
    c=df["median_house_value"],
    cmap="viridis",
    s=100,
    alpha=0.7,
)
plt.colorbar(
    scatter, label="Median House Value"
)  # Associate colorbar with scatter plot
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Spatial Distribution of Housing Prices")
plt.xticks(np.arange(-124, -113, 1))
plt.yticks(np.arange(32, 43, 1))
plt.show()
